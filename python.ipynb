# %%
users = ["ali K", "  khan GG", "  TalHA AD  "]

# %%
def clean_data(user_data):
    temp =[]
    for user in user_data:
        temp.append(user.strip().title())
    
    return temp

# %%
data = clean_data(users)

# %%
data
# Out:
# ['Ali K', 'Khan Gg', 'Talha Ad']
